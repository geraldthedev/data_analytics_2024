# %%
import requests, json
import pandas as pd
import numpy as np

url = f"https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=s1yaDU7DcJ9coRcH4uV7cL0FmpsnsqiZ"


data = json.loads(requests.get(url).text)['results']

data_graph = pd.DataFrame(data).head()

data_graph
# Out:
#                                                  uri  \
# 0  nyt://article/a1dd8356-a64d-5376-bef4-e7545ebb...
# 1  nyt://article/ffe20a1e-2c23-5d6b-b893-a1c659eb...
# 2  nyt://article/f7adb208-b4c3-5bca-a989-5253ad06...
# 3  nyt://article/57fb3841-ed78-5a07-a393-56b164a9...
# 4  nyt://article/8996a0a8-5505-52f5-8217-434c3fd4...
#
#                                                  url               id  \
# 0  https://www.nytimes.com/2024/11/14/business/tr...  100000009823727
# 1  https://www.nytimes.com/2024/11/13/us/death-st...  100000009789626
# 2  https://www.nytimes.com/2024/11/14/opinion/i-c...  100000009826135
# 3  https://www.nytimes.com/2024/11/13/us/politics...  100000009824632
# 4  https://www.nytimes.com/2024/11/13/style/co-wo...  100000009802439
#
#           asset_id          source published_date              updated  \
# 0  100000009823727  New York Times     2024-11-14  2024-11-14 21:09:06
# 1  100000009789626  New York Times     2024-11-13  2024-11-13 11:05:32
# ...
